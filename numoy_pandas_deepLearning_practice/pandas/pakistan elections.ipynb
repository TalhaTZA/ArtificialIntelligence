# %%
import pandas as pd

# %%
data=pd.read_csv("data.csv")

# %%
data
# Out:
#      District                     Seat Constituency_title  \
# 0     Chitral                  Chitral               NA-1
# 1     Chitral                  Chitral               NA-1
# 2     Chitral                  Chitral               NA-1
# 3     Chitral                  Chitral               NA-1
# 4     Chitral                  Chitral               NA-1
# 5     Chitral                  Chitral               NA-1
# 6     Chitral                  Chitral               NA-1
# 7     Chitral                  Chitral               NA-1
# 8     Chitral                  Chitral               NA-1
# 9     Chitral                  Chitral               NA-1
# 10    Chitral                  Chitral               NA-1
# 11       Swat                   Swat-I              NA-2
# 12       Swat                   Swat-I              NA-2
# 13       Swat                   Swat-I              NA-2
# 14       Swat                   Swat-I              NA-2
# ...

# %%
data.columns
# Out:
# Index(['District', 'Seat', 'Constituency_title', 'Candidate_Name', 'Party'], dtype='object')

# %%
data.groupby(['Constituency_title']).count()
# Out:
#                     District  Seat  Candidate_Name  Party
# Constituency_title
#  NA-112                   14    14              14     14
#  NA-113                   17    17              17     17
# NA- 14                     3     3               3      3
# NA-1                      11    11              11     11
# NA-10                      9     9               9      9
# NA-100                    13    13              13     13
# NA-101                    14    14              14     14
# NA-102                    16    16              16     16
# NA-103                    10    10              10     10
# NA-104                    14    14              14     14
# NA-105                    13    13              13     13
# NA-106                     8     8               8      8
# NA-107                     7     7               7      7
# NA-108                     8     8               8      8
# NA-109                    10    10              10     10
# ...

# %%
data[data.Constituency_title=='NA-256']
# Out:
#       District                Seat Constituency_title  \
# 2867  Karachi   Karachi Central-IV             NA-256
# 2868  Karachi   Karachi Central-IV             NA-256
# 2869  Karachi   Karachi Central-IV             NA-256
# 2870  Karachi   Karachi Central-IV             NA-256
# 2871  Karachi   Karachi Central-IV             NA-256
# 2872  Karachi   Karachi Central-IV             NA-256
# 2873  Karachi   Karachi Central-IV             NA-256
# 2874  Karachi   Karachi Central-IV             NA-256
# 2875  Karachi   Karachi Central-IV             NA-256
# 2876  Karachi   Karachi Central-IV             NA-256
# 2877  Karachi   Karachi Central-IV             NA-256
# 2878  Karachi   Karachi Central-IV             NA-256
# 2879  Karachi   Karachi Central-IV             NA-256
# 2880  Karachi   Karachi Central-IV             NA-256
# 2881  Karachi   Karachi Central-IV             NA-256
# 2882  Karachi   Karachi Central-IV             NA-256
#
# ...

# %%
data[(data.Party=='Pakistan Tehreek-e-Insaf') & (data.Candidate_Name=='Imran Ahmed Khan Niazi')]
# Out:
#       District             Seat Constituency_title          Candidate_Name  \
# 2667  Karachi   Karachi East-II             NA-243  Imran Ahmed Khan Niazi
#
#                          Party
# 2667  Pakistan Tehreek-e-Insaf

# %%
data[(data.Party=='Pakistan Tehreek-e-Insaf') | (data.Party=='Mutthida majlis-e-Amal Pakistan')].count()
# Out:
# District              97
# Seat                  97
# Constituency_title    97
# Candidate_Name        97
# Party                 97
# dtype: int64

# %%
data.groupby('Constituency_title').count()
# Out:
#                     District  Seat  Candidate_Name  Party
# Constituency_title
#  NA-112                   14    14              14     14
#  NA-113                   17    17              17     17
# NA- 14                     3     3               3      3
# NA-1                      11    11              11     11
# NA-10                      9     9               9      9
# NA-100                    13    13              13     13
# NA-101                    14    14              14     14
# NA-102                    16    16              16     16
# NA-103                    10    10              10     10
# NA-104                    14    14              14     14
# NA-105                    13    13              13     13
# NA-106                     8     8               8      8
# NA-107                     7     7               7      7
# NA-108                     8     8               8      8
# NA-109                    10    10              10     10
# ...

# %%
data.groupby('Constituency_title')['Seat'].count().nlargest(10)
# Out:
# Constituency_title
# NA-45     39
# NA-48     35
# NA-53     33
# NA-259    31
# NA-50     28
# NA-54     28
# NA-44     26
# NA-17     25
# NA-207    25
# NA-260    25
# Name: Seat, dtype: int64

# %%
data.groupby('Constituency_title')['Seat'].count().nsmallest(10)
# Out:
# Constituency_title
# NA-18     1
# NA- 14    3
# NA-14     4
# NA? 14    4
# NA-160    5
# NA-186    5
# NA-190    5
# NA-20     5
# NA-29     5
# NA-119    6
# Name: Seat, dtype: int64

# %%
from fuzzywuzzy import fuzz
# Out:
# D:\anacinda\lib\site-packages\fuzzywuzzy\fuzz.py:35: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
parties=pd.read_csv('parties.csv')

# %%
def resolveParty(x):
    max=0
    match=''
    for i in parties['Name of Political Party']:
        r=fuzz.ratio(x,i)
        if r>max:
            max=r
            match=i
    return match

# %%
extracted_parties=data.Party.apply(resolveParty)

# %%
data.Party=extracted_parties

# %%
seats=data.groupby(['Party'])['Seat'].count()

# %%
party_position=seats.nlargest(11)

# %%
party_position
# Out:
# Party
# Independent                                1371
# Pakistan Peoples Party Parliamentarians     219
# Pakistan Tehreek-e-Insaf                    218
# Pakistan Muslim League (N)                  186
# Tehreek Labbaik Pakistan                    160
# National Party                              152
# Mutahida Majlis-e-Amal Pakistan             131
# Allah-O-Akbar Tehreek                        62
# Awami National Party                         62
# Pak Sarzameen Party                          51
# All Pakistan Muslim League                   42
# Name: Seat, dtype: int64
